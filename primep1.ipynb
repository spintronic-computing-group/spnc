# %%
import sys
from pathlib import Path


import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.metrics import classification_report


from spnc import spnc_anisotropy
import spnc_ml as ml

# %%
def NRMSE(Y,Y_pred):
    var = np.var(Y)
    return np.sqrt(np.square(Y_pred-Y).mean()/var)

def NRMSE_list(y,y_pred):
    Y = np.array(y)
    Y_pred = np.array(y_pred)
    return(NRMSE(Y,Y_pred))

# %% [markdown]
# set primep1 = 0.51; restart = true

# %%
import spnc 
import spnc_ml as ml
import importlib
importlib.reload(spnc)
importlib.reload(ml)

# NARMA10 parameters
Ntrain = 2000
Ntest = 1000

# Net parameters
Nvirt = 30
m0 = 0.003
bias = True

# Reservoir parameters
h = 0.4
theta_H = 90
k_s_0 = 0
phi = 45
beta_prime = 20

# Params
params = {
    'theta':0.3, 
    'gamma':.113, 
    'delay_feedback':0, 
    'Nvirt':Nvirt,
    'noise_enable': 'None',
    'noise_std':0.00013,
    'train_sample': Ntrain,
    'test_sample': Ntest
}


spn = spnc_anisotropy(h, theta_H, k_s_0, phi, beta_prime,restart = True,Primep1=0.51)
# transforms = spn.gen_signal_slow_delayed_feedback
transformf = spn.gen_signal_fast_delayed_feedback

# run
# (y_test_s,y_pred_s) = ml.spnc_narma10(Ntrain,Ntest,Nvirt,m0,bias,transforms,params,seed_NARMA=1234,fixed_mask=True,return_outputs=True)
# run
(y_test_f,y_pred_f) = ml.spnc_narma10(Ntrain,Ntest,Nvirt,m0,bias,transformf,params,seed_NARMA=1234,fixed_mask=True,return_outputs=True)
# Out:
# seed NARMA: 1234
# Samples for training:  2000
# Samples for test:  1000
# Nin = 1 , Nout =  2000 , Nvirt =  30
# Deterministic mask will be used
# 1234
# Attributes and values of the instance associated with res:
#
# interdensity: 100
# restart: True
# Primep1: 0.51
# h: 0.4
# theta_H: 90
# k_s: 0
# phi: 45
# beta_prime: 20
# e_12_small: 0.3599999363021649
# e_21_small: 0.35999998072247896
# e_12_big: 1.9599999165590078
# e_21_big: 1.959999960979322
# theta_1: 23.56435643564356
# theta_2: 156.41764176417644
# f0: 10000000000.0
# p1: 0.49999977789842975
# p2: 0.5000002221015702
# f_theta_1: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C5A9F8>
# f_theta_2: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2AB8958>
# f_e_12_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C698B8>
# f_e_21_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C697C8>
# f_e_12_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C694F8>
# f_e_21_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2A97408>
# f_p1_eq: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2A97138>
# f_om_tot: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2A97278>
# p1 in fast: 0.51
# restarted
# noise-free output
# Seed Training: 1234
# Attributes and values of the instance associated with res:
#
# interdensity: 100
# restart: True
# Primep1: 0.51
# h: 0.4
# theta_H: 90
# k_s: 0
# phi: 45
# beta_prime: 20
# e_12_small: 0.3599999363021649
# e_21_small: 0.35999998072247896
# e_12_big: 1.9599999165590078
# e_21_big: 1.959999960979322
# theta_1: 23.56435643564356
# theta_2: 156.41764176417644
# f0: 10000000000.0
# p1: 0.49999977789842975
# p2: 0.5000002221015702
# f_theta_1: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C3AD18>
# f_theta_2: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2A9AF48>
# f_e_12_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C3BC78>
# f_e_21_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C663B8>
# f_e_12_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BD2C28>
# f_e_21_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BD5048>
# f_p1_eq: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2A97638>
# f_om_tot: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2A97458>
# p1 in fast: 0.51
# restarted
# noise-free output
# Spacer NRMSE:0
# 0.007276688479130402 0.770810898417332

# %% [markdown]
# primep1 = 0.51, restart = false

# %%
import spnc 
import spnc_ml as ml
import importlib
importlib.reload(spnc)
importlib.reload(ml)

# NARMA10 parameters
Ntrain = 2000
Ntest = 1000

# Net parameters
Nvirt = 30
m0 = 0.003
bias = True

# Reservoir parameters
h = 0.4
theta_H = 90
k_s_0 = 0
phi = 45
beta_prime = 20

# Params
params = {
    'theta':0.3, 
    'gamma':.113, 
    'delay_feedback':0, 
    'Nvirt':Nvirt,
    'noise_enable': 'None',
    'noise_std':0.00013,
    'train_sample': Ntrain,
    'test_sample': Ntest
}


spn = spnc_anisotropy(h, theta_H, k_s_0, phi, beta_prime,restart = False,Primep1=0.51)
# transforms = spn.gen_signal_slow_delayed_feedback
transformf = spn.gen_signal_fast_delayed_feedback

# run
# (y_test_s,y_pred_s) = ml.spnc_narma10(Ntrain,Ntest,Nvirt,m0,bias,transforms,params,seed_NARMA=1234,fixed_mask=True,return_outputs=True)
# run
(y_test_f,y_pred_f) = ml.spnc_narma10(Ntrain,Ntest,Nvirt,m0,bias,transformf,params,seed_NARMA=1234,fixed_mask=True,return_outputs=True)
# Out:
# seed NARMA: 1234
# Samples for training:  2000
# Samples for test:  1000
# Nin = 1 , Nout =  2000 , Nvirt =  30
# Deterministic mask will be used
# 1234
# Attributes and values of the instance associated with res:
#
# interdensity: 100
# restart: False
# Primep1: 0.51
# h: 0.4
# theta_H: 90
# k_s: 0
# phi: 45
# beta_prime: 20
# e_12_small: 0.3599999363021649
# e_21_small: 0.35999998072247896
# e_12_big: 1.9599999165590078
# e_21_big: 1.959999960979322
# theta_1: 23.56435643564356
# theta_2: 156.41764176417644
# f0: 10000000000.0
# p1: 0.49999977789842975
# p2: 0.5000002221015702
# f_theta_1: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BE2B38>
# f_theta_2: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C35598>
# f_e_12_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2AB89A8>
# f_e_21_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C64B88>
# f_e_12_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C4B7C8>
# f_e_21_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C669A8>
# f_p1_eq: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2B36EF8>
# f_om_tot: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2B36188>
# p1 in fast: 0.51
# skip restarting..
# noise-free output
# Seed Training: 1234
# Attributes and values of the instance associated with res:
#
# interdensity: 100
# restart: False
# Primep1: 0.51
# h: 0.4
# theta_H: 90
# k_s: [-0.00044524]
# phi: 45
# beta_prime: 20
# e_12_small: 0.3599999363021649
# e_21_small: 0.35999998072247896
# e_12_big: 1.9599999165590078
# e_21_big: 1.959999960979322
# theta_1: 23.56435643564356
# theta_2: 156.41764176417644
# f0: 10000000000.0
# p1: [0.49692302]
# p2: [0.50307698]
# f_theta_1: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BE2B38>
# f_theta_2: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C35598>
# f_e_12_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2AB89A8>
# f_e_21_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C64B88>
# f_e_12_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C4B7C8>
# f_e_21_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C669A8>
# f_p1_eq: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2B36EF8>
# f_om_tot: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2B36188>
# p1 in fast: 0.51
# skip restarting..
# noise-free output
# Spacer NRMSE:0
# 0.007276688479130402 0.770810898417332

# %% [markdown]
# primep1 = none, restart = true

# %%
import spnc 
import spnc_ml as ml
import importlib
importlib.reload(spnc)
importlib.reload(ml)

# NARMA10 parameters
Ntrain = 2000
Ntest = 1000

# Net parameters
Nvirt = 30
m0 = 0.003
bias = True

# Reservoir parameters
h = 0.4
theta_H = 90
k_s_0 = 0
phi = 45
beta_prime = 20

# Params
params = {
    'theta':0.3, 
    'gamma':.113, 
    'delay_feedback':0, 
    'Nvirt':Nvirt,
    'noise_enable': 'None',
    'noise_std':0.00013,
    'train_sample': Ntrain,
    'test_sample': Ntest
}


spn = spnc_anisotropy(h, theta_H, k_s_0, phi, beta_prime,restart = True,Primep1=None)
# transforms = spn.gen_signal_slow_delayed_feedback
transformf = spn.gen_signal_fast_delayed_feedback

# run
# (y_test_s,y_pred_s) = ml.spnc_narma10(Ntrain,Ntest,Nvirt,m0,bias,transforms,params,seed_NARMA=1234,fixed_mask=True,return_outputs=True)
# run
(y_test_f,y_pred_f) = ml.spnc_narma10(Ntrain,Ntest,Nvirt,m0,bias,transformf,params,seed_NARMA=1234,fixed_mask=True,return_outputs=True)
# Out:
# seed NARMA: 1234
# Samples for training:  2000
# Samples for test:  1000
# Nin = 1 , Nout =  2000 , Nvirt =  30
# Deterministic mask will be used
# 1234
# Attributes and values of the instance associated with res:
#
# interdensity: 100
# restart: True
# Primep1: None
# h: 0.4
# theta_H: 90
# k_s: 0
# phi: 45
# beta_prime: 20
# e_12_small: 0.3599999363021649
# e_21_small: 0.35999998072247896
# e_12_big: 1.9599999165590078
# e_21_big: 1.959999960979322
# theta_1: 23.56435643564356
# theta_2: 156.41764176417644
# f0: 10000000000.0
# p1: 0.49999977789842975
# p2: 0.5000002221015702
# f_theta_1: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2AC41D8>
# f_theta_2: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BE29A8>
# f_e_12_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BAFC78>
# f_e_21_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BAF048>
# f_e_12_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BACAE8>
# f_e_21_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BACE08>
# f_p1_eq: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BAC368>
# f_om_tot: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BAC8B8>
# p1 in fast: 0.49999977789842975
# restarted
# noise-free output
# Seed Training: 1234
# Attributes and values of the instance associated with res:
#
# interdensity: 100
# restart: True
# Primep1: None
# h: 0.4
# theta_H: 90
# k_s: 0
# phi: 45
# beta_prime: 20
# e_12_small: 0.3599999363021649
# e_21_small: 0.35999998072247896
# e_12_big: 1.9599999165590078
# e_21_big: 1.959999960979322
# theta_1: 23.56435643564356
# theta_2: 156.41764176417644
# f0: 10000000000.0
# p1: 0.49999977789842975
# p2: 0.5000002221015702
# f_theta_1: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C35598>
# f_theta_2: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2AB5DB8>
# f_e_12_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C64908>
# f_e_21_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2C4B9A8>
# f_e_12_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BA99F8>
# f_e_21_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BA9818>
# f_p1_eq: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BACEF8>
# f_om_tot: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BACD68>
# p1 in fast: 0.49999977789842975
# restarted
# noise-free output
# Spacer NRMSE:0
# 0.004620522927707696 0.6142236293701125

# %% [markdown]
# primep1 = none, restart = false

# %%
import spnc 
import spnc_ml as ml
import importlib
importlib.reload(spnc)
importlib.reload(ml)

# NARMA10 parameters
Ntrain = 2000
Ntest = 1000

# Net parameters
Nvirt = 30
m0 = 0.003
bias = True

# Reservoir parameters
h = 0.4
theta_H = 90
k_s_0 = 0
phi = 45
beta_prime = 20

# Params
params = {
    'theta':0.3, 
    'gamma':.113, 
    'delay_feedback':0, 
    'Nvirt':Nvirt,
    'noise_enable': 'None',
    'noise_std':0.00013,
    'train_sample': Ntrain,
    'test_sample': Ntest
}


spn = spnc_anisotropy(h, theta_H, k_s_0, phi, beta_prime,restart = False,Primep1=None)
# transforms = spn.gen_signal_slow_delayed_feedback
transformf = spn.gen_signal_fast_delayed_feedback

# run
# (y_test_s,y_pred_s) = ml.spnc_narma10(Ntrain,Ntest,Nvirt,m0,bias,transforms,params,seed_NARMA=1234,fixed_mask=True,return_outputs=True)
# run
(y_test_f,y_pred_f) = ml.spnc_narma10(Ntrain,Ntest,Nvirt,m0,bias,transformf,params,seed_NARMA=1234,fixed_mask=True,return_outputs=True)
# Out:
# seed NARMA: 1234
# Samples for training:  2000
# Samples for test:  1000
# Nin = 1 , Nout =  2000 , Nvirt =  30
# Deterministic mask will be used
# 1234
# Attributes and values of the instance associated with res:
#
# interdensity: 100
# restart: False
# Primep1: None
# h: 0.4
# theta_H: 90
# k_s: 0
# phi: 45
# beta_prime: 20
# e_12_small: 0.3599999363021649
# e_21_small: 0.35999998072247896
# e_12_big: 1.9599999165590078
# e_21_big: 1.959999960979322
# theta_1: 23.56435643564356
# theta_2: 156.41764176417644
# f0: 10000000000.0
# p1: 0.49999977789842975
# p2: 0.5000002221015702
# f_theta_1: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2E0DEA8>
# f_theta_2: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BAF7C8>
# f_e_12_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BAF188>
# f_e_21_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2DF2368>
# f_e_12_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2B47188>
# f_e_21_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2E11D68>
# f_p1_eq: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2DF8548>
# f_om_tot: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2DF8318>
# p1 in fast: 0.49999977789842975
# skip restarting..
# noise-free output
# Seed Training: 1234
# Attributes and values of the instance associated with res:
#
# interdensity: 100
# restart: False
# Primep1: None
# h: 0.4
# theta_H: 90
# k_s: [-0.00044524]
# phi: 45
# beta_prime: 20
# e_12_small: 0.3599999363021649
# e_21_small: 0.35999998072247896
# e_12_big: 1.9599999165590078
# e_21_big: 1.959999960979322
# theta_1: 23.56435643564356
# theta_2: 156.41764176417644
# f0: 10000000000.0
# p1: [0.49692302]
# p2: [0.50307698]
# f_theta_1: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2E0DEA8>
# f_theta_2: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BAF7C8>
# f_e_12_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2BAF188>
# f_e_21_small: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2DF2368>
# f_e_12_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2B47188>
# f_e_21_big: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2E11D68>
# f_p1_eq: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2DF8548>
# f_om_tot: <scipy.interpolate.interpolate.interp1d object at 0x00000218F2DF8318>
# p1 in fast: [0.49692302]
# skip restarting..
# noise-free output
# Spacer NRMSE:0
# 18.3299485547605 38.68669041373567
